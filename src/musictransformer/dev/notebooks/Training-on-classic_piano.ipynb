# %%
# %load_ext autoreload
# %autoreload 2
# %cd ../MusicTransformer-tensorflow2.0

from train import train
train(
    '/data/classic_piano_preprocessed',
    './save',
    log_dir='/tmp/logs/classic_piano_preprocessed')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /notebooks/src/MusicTransformer-tensorflow2.0
# ...

# %%
# !python3 train.py \
    --input_path /data/classic_piano_preprocessed \
    --epochs=30 --save_path=./save --max_seq=2048 \
    --pickle_dir=./pickle --batch_size=2
